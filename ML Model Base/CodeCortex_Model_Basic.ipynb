# %%
# !pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.17.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (71.0.4)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.64.1)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.17.0)
# Requirement already satisfied: keras>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.44.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (13.8.1)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (0.12.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2024.8.30)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.0.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow) (2.1.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->tensorflow) (0.1.2)

# %%
import numpy as np
import pandas as pd
from sklearn.utils import shuffle
import os
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
import tensorflow as tf
from tensorflow.keras.utils import to_categorical
from keras.preprocessing.image import load_img
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, Dropout, Flatten, MaxPooling2D

# %%
# !pip install kaggle==1.5.12
# Out:
# Requirement already satisfied: kaggle==1.5.12 in /usr/local/lib/python3.10/dist-packages (1.5.12)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.10/dist-packages (from kaggle==1.5.12) (1.16.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from kaggle==1.5.12) (2024.8.30)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from kaggle==1.5.12) (2.8.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from kaggle==1.5.12) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from kaggle==1.5.12) (4.66.5)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.10/dist-packages (from kaggle==1.5.12) (8.0.4)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from kaggle==1.5.12) (2.2.3)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.10/dist-packages (from python-slugify->kaggle==1.5.12) (1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->kaggle==1.5.12) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->kaggle==1.5.12) (3.10)

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d aadityasinghal/facial-expression-dataset -p /content/dataset_directory
# Out:
# facial-expression-dataset.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
import zipfile

with zipfile.ZipFile('/content/dataset_directory/facial-expression-dataset.zip', 'r') as zip_ref:
  zip_ref.extractall('/content/dataset_directory')

# %%
TRAIN_DIR = '/content/dataset_directory/train/train/'
TEST_DIR = '/content/dataset_directory/test/test/'

# %%
def load_dataset(directory):
    image_paths = []
    labels = []

    for label in os.listdir(directory):
        for filename in os.listdir(directory+label):
            image_path = os.path.join(directory, label, filename)
            image_paths.append(image_path)
            labels.append(label)

        print(label, "Completed")

    return image_paths, labels

# %%
train = pd.DataFrame()
train['image'], train['label'] = load_dataset(TRAIN_DIR)
train = train.sample(frac=1).reset_index(drop=True)
train.head()
# Out:
# sad Completed
# surprise Completed
# disgust Completed
# fear Completed
# angry Completed
# happy Completed
# neutral Completed
#                                                image  label
# 0  /content/dataset_directory/train/train/happy/T...  happy
# 1  /content/dataset_directory/train/train/angry/T...  angry
# 2  /content/dataset_directory/train/train/fear/Tr...   fear
# 3  /content/dataset_directory/train/train/fear/Tr...   fear
# 4  /content/dataset_directory/train/train/happy/T...  happy

# %%
test = pd.DataFrame()
test['image'], test['label'] = load_dataset(TEST_DIR)
test.head()
# Out:
# sad Completed
# surprise Completed
# disgust Completed
# fear Completed
# angry Completed
# happy Completed
# neutral Completed
#                                                image label
# 0  /content/dataset_directory/test/test/sad/Publi...   sad
# 1  /content/dataset_directory/test/test/sad/Publi...   sad
# 2  /content/dataset_directory/test/test/sad/Priva...   sad
# 3  /content/dataset_directory/test/test/sad/Priva...   sad
# 4  /content/dataset_directory/test/test/sad/Publi...   sad

# %%
sns.countplot(train['label'])
# Out:
# <Axes: xlabel='count', ylabel='label'>

# %%
from PIL import Image
img = Image.open(train['image'][0])
plt.imshow(img, cmap='gray')

# %%
files = shuffle(train.iloc[0:25])

plt.figure(figsize=(20, 20))

for index, file, label in files.itertuples():
    plt.subplot(5, 5, index+1)
    img = load_img(file)
    img = np.array(img)
    plt.imshow(img)
    plt.title(label)
    plt.axis('off')

plt.show()

# %%
# !pip install tqdm
from tqdm import tqdm
# Out:
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (4.66.5)

# %%
def extract_features(images):
  features = []
  for image in tqdm(images):
    img = Image.open(image).convert('L')
    img = np.array(img)
    features.append(img)

  features = np.array(features)
  features = features.reshape(len(features), 48,48,1)
  return features

# %%
train_features = extract_features(train['image'])
# Out:
# 100%|██████████| 28709/28709 [00:11<00:00, 2395.80it/s]

# %%
test_features = extract_features(test['image'])
# Out:
# 100%|██████████| 7178/7178 [00:02<00:00, 3355.42it/s]

# %%
x_train = train_features/255.0
x_test = test_features/255.0

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
le.fit(train['label'])
y_train = le.transform(train['label'])
y_test= le.transform(test['label'])

# %%
y_train = to_categorical(y_train, num_classes=7)
y_test = to_categorical(y_test, num_classes=7)

# %%
input_shape = (48,48,1)
output_class = 7

# %%
model = Sequential()

#CNN Layers

#Layer 1
model.add(Conv2D(128, kernel_size=(3,3), activation='relu', input_shape=input_shape))
model.add(MaxPooling2D(pool_size = (2,2)))
model.add(Dropout(0.4))

#Layer 2
model.add(Conv2D(256, kernel_size=(3,3), activation='relu'))
model.add(MaxPooling2D(pool_size = (2,2)))
model.add(Dropout(0.4))

#Layer 3
model.add(Conv2D(512, kernel_size=(3,3), activation='relu'))
model.add(MaxPooling2D(pool_size = (2,2)))
model.add(Dropout(0.4))

#Layer 4
model.add(Conv2D(512, kernel_size=(3,3), activation='relu', input_shape=input_shape))
model.add(MaxPooling2D(pool_size = (2,2)))
model.add(Dropout(0.4))


model.add(Flatten())

#Connected Layer
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.3))

#O/P Layer
model.add(Dense(output_class, activation='softmax'))

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(x=x_train, y=y_train, batch_size=128, epochs=100, validation_data=(x_test,y_test))
# Out:
# Epoch 1/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 37s 83ms/step - accuracy: 0.2399 - loss: 1.8400 - val_accuracy: 0.2471 - val_loss: 1.8174
# Epoch 2/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 10s 44ms/step - accuracy: 0.2597 - loss: 1.8019 - val_accuracy: 0.2471 - val_loss: 1.7967
# Epoch 3/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 10s 44ms/step - accuracy: 0.2636 - loss: 1.7745 - val_accuracy: 0.3225 - val_loss: 1.6666
# Epoch 4/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - accuracy: 0.3136 - loss: 1.6893 - val_accuracy: 0.3986 - val_loss: 1.5146
# Epoch 5/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - accuracy: 0.3982 - loss: 1.5449 - val_accuracy: 0.4613 - val_loss: 1.3890
# Epoch 6/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 10s 46ms/step - accuracy: 0.4330 - loss: 1.4680 - val_accuracy: 0.4742 - val_loss: 1.3506
# Epoch 7/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 11s 46ms/step - accuracy: 0.4557 - loss: 1.4217 - val_accuracy: 0.4948 - val_loss: 1.3190
# Epoch 8/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 10s 46ms/step - accuracy: 0.4699 - loss: 1.3915 - val_accuracy: 0.4978 - val_loss: 1.2865
# Epoch 9/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 20s 45ms/step - accuracy: 0.4832 - loss: 1.3546 - val_accuracy: 0.5061 - val_loss: 1.2641
# Epoch 10/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - accuracy: 0.4885 - loss: 1.3285 - val_accuracy: 0.5309 - val_loss: 1.2205
# Epoch 11/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 10s 46ms/step - accuracy: 0.5054 - loss: 1.2969 - val_accuracy: 0.5339 - val_loss: 1.2128
# Epoch 12/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 20s 45ms/step - accuracy: 0.5161 - loss: 1.2811 - val_accuracy: 0.5499 - val_loss: 1.1750
# Epoch 13/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - accuracy: 0.5171 - loss: 1.2665 - val_accuracy: 0.5497 - val_loss: 1.1684
# Epoch 14/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - accuracy: 0.5247 - loss: 1.2489 - val_accuracy: 0.5593 - val_loss: 1.1623
# Epoch 15/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - accuracy: 0.5360 - loss: 1.2163 - val_accuracy: 0.5543 - val_loss: 1.1505
# Epoch 16/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - accuracy: 0.5361 - loss: 1.2167 - val_accuracy: 0.5591 - val_loss: 1.1403
# Epoch 17/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - accuracy: 0.5448 - loss: 1.1992 - val_accuracy: 0.5612 - val_loss: 1.1371
# Epoch 18/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - accuracy: 0.5494 - loss: 1.1850 - val_accuracy: 0.5591 - val_loss: 1.1354
# Epoch 19/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - accuracy: 0.5547 - loss: 1.1792 - val_accuracy: 0.5660 - val_loss: 1.1343
# Epoch 20/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - accuracy: 0.5534 - loss: 1.1704 - val_accuracy: 0.5791 - val_loss: 1.1038
# Epoch 21/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 20s 45ms/step - accuracy: 0.5606 - loss: 1.1641 - val_accuracy: 0.5770 - val_loss: 1.1087
# Epoch 22/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 20s 45ms/step - accuracy: 0.5606 - loss: 1.1617 - val_accuracy: 0.5825 - val_loss: 1.0989
# Epoch 23/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - accuracy: 0.5660 - loss: 1.1432 - val_accuracy: 0.5825 - val_loss: 1.0853
# Epoch 24/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - accuracy: 0.5673 - loss: 1.1296 - val_accuracy: 0.5889 - val_loss: 1.0795
# Epoch 25/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 10s 46ms/step - accuracy: 0.5731 - loss: 1.1276 - val_accuracy: 0.5900 - val_loss: 1.0850
# Epoch 26/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - accuracy: 0.5779 - loss: 1.1199 - val_accuracy: 0.5901 - val_loss: 1.0817
# Epoch 27/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - accuracy: 0.5836 - loss: 1.1014 - val_accuracy: 0.5908 - val_loss: 1.0786
# Epoch 28/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 10s 46ms/step - accuracy: 0.5803 - loss: 1.1092 - val_accuracy: 0.5829 - val_loss: 1.0793
# Epoch 29/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 22s 51ms/step - accuracy: 0.5878 - loss: 1.0882 - val_accuracy: 0.5885 - val_loss: 1.0805
# Epoch 30/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 19s 45ms/step - accuracy: 0.5876 - loss: 1.0883 - val_accuracy: 0.5921 - val_loss: 1.0686
# Epoch 31/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 10s 46ms/step - accuracy: 0.5920 - loss: 1.0766 - val_accuracy: 0.5977 - val_loss: 1.0645
# Epoch 32/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 21s 47ms/step - accuracy: 0.5953 - loss: 1.0660 - val_accuracy: 0.5871 - val_loss: 1.0647
# Epoch 33/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 21s 50ms/step - accuracy: 0.5979 - loss: 1.0569 - val_accuracy: 0.5946 - val_loss: 1.0679
# Epoch 34/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 20s 47ms/step - accuracy: 0.6004 - loss: 1.0542 - val_accuracy: 0.5964 - val_loss: 1.0627
# Epoch 35/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 21s 49ms/step - accuracy: 0.6071 - loss: 1.0418 - val_accuracy: 0.5974 - val_loss: 1.0640
# Epoch 36/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 20s 47ms/step - accuracy: 0.6099 - loss: 1.0376 - val_accuracy: 0.6021 - val_loss: 1.0574
# Epoch 37/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 21s 48ms/step - accuracy: 0.6058 - loss: 1.0490 - val_accuracy: 0.5963 - val_loss: 1.0572
# Epoch 38/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 23s 59ms/step - accuracy: 0.6158 - loss: 1.0249 - val_accuracy: 0.5938 - val_loss: 1.0555
# Epoch 39/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 17s 45ms/step - accuracy: 0.6185 - loss: 1.0161 - val_accuracy: 0.6053 - val_loss: 1.0498
# Epoch 40/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - accuracy: 0.6168 - loss: 1.0246 - val_accuracy: 0.6002 - val_loss: 1.0569
# Epoch 41/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - accuracy: 0.6176 - loss: 1.0199 - val_accuracy: 0.6004 - val_loss: 1.0585
# Epoch 42/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - accuracy: 0.6196 - loss: 1.0050 - val_accuracy: 0.6092 - val_loss: 1.0388
# Epoch 43/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - accuracy: 0.6265 - loss: 0.9934 - val_accuracy: 0.6130 - val_loss: 1.0395
# Epoch 44/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - accuracy: 0.6340 - loss: 0.9855 - val_accuracy: 0.6013 - val_loss: 1.0470
# Epoch 45/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - accuracy: 0.6313 - loss: 0.9759 - val_accuracy: 0.6091 - val_loss: 1.0472
# Epoch 46/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 11s 49ms/step - accuracy: 0.6321 - loss: 0.9796 - val_accuracy: 0.6074 - val_loss: 1.0415
# Epoch 47/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 12s 53ms/step - accuracy: 0.6345 - loss: 0.9777 - val_accuracy: 0.6010 - val_loss: 1.0485
# Epoch 48/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 10s 46ms/step - accuracy: 0.6336 - loss: 0.9678 - val_accuracy: 0.6095 - val_loss: 1.0403
# Epoch 49/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 20s 45ms/step - accuracy: 0.6382 - loss: 0.9589 - val_accuracy: 0.6103 - val_loss: 1.0373
# Epoch 50/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 10s 46ms/step - accuracy: 0.6457 - loss: 0.9532 - val_accuracy: 0.6092 - val_loss: 1.0397
# Epoch 51/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 20s 45ms/step - accuracy: 0.6466 - loss: 0.9441 - val_accuracy: 0.6081 - val_loss: 1.0324
# Epoch 52/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 10s 46ms/step - accuracy: 0.6512 - loss: 0.9399 - val_accuracy: 0.6082 - val_loss: 1.0367
# Epoch 53/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 20s 45ms/step - accuracy: 0.6467 - loss: 0.9489 - val_accuracy: 0.6117 - val_loss: 1.0380
# Epoch 54/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - accuracy: 0.6442 - loss: 0.9481 - val_accuracy: 0.6130 - val_loss: 1.0414
# Epoch 55/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - accuracy: 0.6503 - loss: 0.9302 - val_accuracy: 0.6149 - val_loss: 1.0305
# Epoch 56/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - accuracy: 0.6573 - loss: 0.9252 - val_accuracy: 0.6154 - val_loss: 1.0374
# Epoch 57/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - accuracy: 0.6583 - loss: 0.9191 - val_accuracy: 0.6195 - val_loss: 1.0263
# Epoch 58/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 10s 46ms/step - accuracy: 0.6632 - loss: 0.9094 - val_accuracy: 0.6205 - val_loss: 1.0234
# Epoch 59/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 20s 45ms/step - accuracy: 0.6545 - loss: 0.9108 - val_accuracy: 0.6130 - val_loss: 1.0330
# Epoch 60/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - accuracy: 0.6588 - loss: 0.9120 - val_accuracy: 0.6190 - val_loss: 1.0307
# Epoch 61/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 10s 46ms/step - accuracy: 0.6631 - loss: 0.8961 - val_accuracy: 0.6110 - val_loss: 1.0311
# Epoch 62/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 20s 45ms/step - accuracy: 0.6680 - loss: 0.8947 - val_accuracy: 0.6102 - val_loss: 1.0352
# Epoch 63/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - accuracy: 0.6655 - loss: 0.8998 - val_accuracy: 0.6109 - val_loss: 1.0403
# Epoch 64/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - accuracy: 0.6622 - loss: 0.8940 - val_accuracy: 0.6151 - val_loss: 1.0339
# Epoch 65/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - accuracy: 0.6717 - loss: 0.8866 - val_accuracy: 0.6158 - val_loss: 1.0299
# Epoch 66/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - accuracy: 0.6735 - loss: 0.8850 - val_accuracy: 0.6213 - val_loss: 1.0239
# Epoch 67/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 10s 46ms/step - accuracy: 0.6685 - loss: 0.8887 - val_accuracy: 0.6152 - val_loss: 1.0287
# Epoch 68/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 20s 45ms/step - accuracy: 0.6738 - loss: 0.8715 - val_accuracy: 0.6208 - val_loss: 1.0289
# Epoch 69/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - accuracy: 0.6774 - loss: 0.8711 - val_accuracy: 0.6233 - val_loss: 1.0302
# Epoch 70/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - accuracy: 0.6832 - loss: 0.8538 - val_accuracy: 0.6173 - val_loss: 1.0255
# Epoch 71/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - accuracy: 0.6868 - loss: 0.8507 - val_accuracy: 0.6193 - val_loss: 1.0255
# Epoch 72/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - accuracy: 0.6844 - loss: 0.8586 - val_accuracy: 0.6205 - val_loss: 1.0218
# Epoch 73/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 10s 46ms/step - accuracy: 0.6898 - loss: 0.8430 - val_accuracy: 0.6226 - val_loss: 1.0319
# Epoch 74/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 20s 45ms/step - accuracy: 0.6889 - loss: 0.8416 - val_accuracy: 0.6186 - val_loss: 1.0305
# Epoch 75/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - accuracy: 0.6875 - loss: 0.8381 - val_accuracy: 0.6265 - val_loss: 1.0234
# Epoch 76/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 20s 45ms/step - accuracy: 0.6891 - loss: 0.8436 - val_accuracy: 0.6225 - val_loss: 1.0223
# Epoch 77/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - accuracy: 0.6943 - loss: 0.8333 - val_accuracy: 0.6241 - val_loss: 1.0328
# Epoch 78/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - accuracy: 0.6948 - loss: 0.8232 - val_accuracy: 0.6240 - val_loss: 1.0308
# Epoch 79/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 10s 46ms/step - accuracy: 0.6908 - loss: 0.8335 - val_accuracy: 0.6255 - val_loss: 1.0248
# Epoch 80/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 10s 46ms/step - accuracy: 0.6988 - loss: 0.8140 - val_accuracy: 0.6290 - val_loss: 1.0188
# Epoch 81/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 10s 46ms/step - accuracy: 0.6979 - loss: 0.8262 - val_accuracy: 0.6268 - val_loss: 1.0204
# Epoch 82/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - accuracy: 0.7064 - loss: 0.7956 - val_accuracy: 0.6232 - val_loss: 1.0314
# Epoch 83/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 10s 46ms/step - accuracy: 0.7048 - loss: 0.8091 - val_accuracy: 0.6225 - val_loss: 1.0286
# Epoch 84/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 10s 46ms/step - accuracy: 0.7038 - loss: 0.8040 - val_accuracy: 0.6212 - val_loss: 1.0300
# Epoch 85/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 20s 45ms/step - accuracy: 0.7059 - loss: 0.8018 - val_accuracy: 0.6272 - val_loss: 1.0345
# Epoch 86/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - accuracy: 0.7061 - loss: 0.7877 - val_accuracy: 0.6219 - val_loss: 1.0394
# Epoch 87/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - accuracy: 0.7121 - loss: 0.7876 - val_accuracy: 0.6265 - val_loss: 1.0265
# Epoch 88/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 10s 46ms/step - accuracy: 0.7124 - loss: 0.7936 - val_accuracy: 0.6283 - val_loss: 1.0191
# Epoch 89/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 10s 46ms/step - accuracy: 0.7181 - loss: 0.7711 - val_accuracy: 0.6219 - val_loss: 1.0370
# Epoch 90/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - accuracy: 0.7144 - loss: 0.7798 - val_accuracy: 0.6282 - val_loss: 1.0363
# Epoch 91/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 20s 45ms/step - accuracy: 0.7127 - loss: 0.7783 - val_accuracy: 0.6251 - val_loss: 1.0382
# Epoch 92/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 20s 45ms/step - accuracy: 0.7165 - loss: 0.7728 - val_accuracy: 0.6236 - val_loss: 1.0381
# Epoch 93/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - accuracy: 0.7220 - loss: 0.7631 - val_accuracy: 0.6280 - val_loss: 1.0382
# Epoch 94/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 10s 46ms/step - accuracy: 0.7188 - loss: 0.7584 - val_accuracy: 0.6261 - val_loss: 1.0342
# Epoch 95/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 20s 45ms/step - accuracy: 0.7155 - loss: 0.7699 - val_accuracy: 0.6268 - val_loss: 1.0391
# Epoch 96/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - accuracy: 0.7191 - loss: 0.7718 - val_accuracy: 0.6265 - val_loss: 1.0269
# Epoch 97/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - accuracy: 0.7254 - loss: 0.7445 - val_accuracy: 0.6240 - val_loss: 1.0415
# Epoch 98/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 20s 45ms/step - accuracy: 0.7238 - loss: 0.7512 - val_accuracy: 0.6307 - val_loss: 1.0245
# Epoch 99/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 21s 46ms/step - accuracy: 0.7313 - loss: 0.7399 - val_accuracy: 0.6273 - val_loss: 1.0312
# Epoch 100/100
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - accuracy: 0.7260 - loss: 0.7522 - val_accuracy: 0.6286 - val_loss: 1.0387

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
epochs = range(len(acc))
plt.plot(epochs, acc, 'b', label='Training Accuracy')
plt.plot(epochs,val_acc,'r', label='Validation Accuracy')
plt.title('Accuracy Porgress')
plt.legend()
# plt.figure()


loss = history.history['loss']
val_loss = history.history['val_loss']
plt.plot(epochs,loss,'b',label='Training Loss')
plt.plot(epochs, val_loss, 'r',label='Validation Loss')
plt.title('Loss Progress')
plt.legend()

plt.show()

# %%
import random

# %%
le.fit(test['label'])

image_index = random.randint(0, len(test) - 1)
print("Original Output: ", test['label'][image_index])


pred = model.predict(x_test[image_index].reshape(1, 48, 48, 1))
prediction_label = le.inverse_transform([pred.argmax()])[0]

print("Predicted Output: ", prediction_label)


plt.imshow(x_test[image_index].reshape(48, 48), cmap='gray')
plt.show()
# Out:
# Original Output:  sad
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Predicted Output:  sad

# %%
model_json = model.to_json()
with open("facialemotionmodel.json", "w") as json_file:
    json_file.write(model_json)

# %%
model.save_weights("facialemotionmodel_weights.weights.h5")

# %%
from google.colab import files
# files.download('facialemotionmodel.json')
files.download('facialemotionmodel_weights.weights.h5')
